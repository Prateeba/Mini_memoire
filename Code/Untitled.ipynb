# %%
import vcsn
ctx = vcsn.context("lat<lal_char(abc), lal_char(abc)>, b")
ctx
# Out:
# {abc} x {abc} -> B

# %%
r = ctx.expression("(\e|\e)* + (\z|\e)* + (a|a)* + (\z|\z)*")
r
# Out:
# \e+\e*+(a|a)*

# %%
r.automaton()
# Out:
# mutable_automaton<context<lat<letterset<char_letters>, letterset<char_letters>>, b>>
