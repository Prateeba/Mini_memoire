# %%
import vcsn

# %%
# %%automaton -s a
# context = "lat<lal_char, lal_char>, b"
#
# $ -> 0
# 0 -> 1 a|x
# 0 -> 2 a|x
# 1 -> 3 b|y
# 2 -> 3 b|y
# 3 -> $
# Out:
# mutable_automaton<context<lat<letterset<char_letters>, letterset<char_letters>>, b>>

# %%
a.is_functional()
# Out:
# True

# %%
a.determinize()
# Out:
# determinized_automaton<mutable_automaton<context<lat<letterset<char_letters>, letterset<char_letters>>, b>>, vcsn::wet_kind_t::bitset, false>

# %%
a.is_trim()
# Out:
# True

# %%
token = input("Enter caracter")
# Out:
# Enter caractera

# %%
print(token)
# Out:
# a

# %%
# %%automaton -s a
# context = "lat<lal_char(ab), lal_char(xy)>, b"
# $ -> 0
# 0 -> 1 token|x
# 0 -> 2 a|x
# 1 -> 3 b|y
# 2 -> 3 b|y
# 3 -> $
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-180-9879022f022f> in <module>()
#       1
# ----> 2 get_ipython().run_cell_magic('automaton', '-s a', 'context = "lat<lal_char(ab), lal_char(xy)>, b"\n$ -> 0\n0 -> 1 token|x\n0 -> 2 a|x\n1 -> 3 b|y\n2 -> 3 b|y\n3 -> $\n    \n')
#
# /usr/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-156> in automaton(self, line, cell)
#
# /usr/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...
