# %%
import matplotlib.pyplot as plt
import numpy as np

states = np.arange(0, 500, 50)
u_states = [4,8,15,17,24,33,34,41,46,56]
plt.plot(states, u_states)

plt.xlabel("Number of total states")
plt.ylabel("Useful States")
plt.title('Useful states according to the total number of states')
plt.savefig("genStop.svg")
plt.show()
